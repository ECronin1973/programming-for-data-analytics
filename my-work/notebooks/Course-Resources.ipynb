# %% [markdown]
# # Introduction
# In this notebook, we will explore various course resources that are essential for mastering programming for data analytics. These resources include online courses, textbooks, and other learning materials that can help you build a strong foundation in programming and data analysis techniques.

# %% [markdown]
# ## Pandas
#
# The pandas DataFrame: Make Working With Data Delightful – Real Python : https://realpython.com/pandas-dataframe/
#
# Using pandas and Python to Explore Your Dataset – Real Python : https://realpython.com/pandas-exploratory-data-analysis/
#
# ## Machine learning
#
# scikit-learn: machine learning in Python — scikit-learn 1.7.1 documentation : https://scikit-learn.org/stable/documentation.html
#
# TensorFlow : https://www.tensorflow.org/
#
# Keras: Deep Learning for humans : https://keras.io/
#
# PyTorch : https://pytorch.org/
#
# ## Python plotting and visualisation
#
# Matplotlib — Visualization with Python : https://matplotlib.org/stable/contents.html
#
# User guide and tutorial — seaborn 0.13.2 documentation : https://seaborn.pydata.org/
#
# Plotly Python Graphing Library : https://plotly.com/python/
#
# ## Data Visualisation (JavaScipt)
#
# D3 by Observable | The JavaScript library for bespoke data visualization : https://observablehq.com/@d3/learn-d3
#
# Examples - Apache ECharts : https://echarts.apache.org/examples/en/index.html
#
# A Visualization Grammar | Vega : https://vega.github.io/vega/

# %% [markdown]
# # Lecture: Representing Data

# %% [markdown]
# ## Iris dataset
#
# The Iris Dataset (github.com) : https://gist.github.com/curran/a08a1080b88344b0c8a7
#
# Convert CSV to CSV Online - Table Convert Online : https://tableconvert.com/csv-to-csv
#
# ## Other APIS
#
# api.irishrail.ie/realtime/ : https://api.irishrail.ie/realtime/
#
# cso.ie : https://cso.ie
#
# andrewbeatty1.pythonanywhere.com/books : https://andrewbeatty1.pythonanywhere.com/books
#
# andrewbeatty1.pythonanywhere.com/books : https://andrewbeatty1.pythonanywhere.com/books
#
# Big List of Free and Open Public APIs (No Auth Needed) [2025] : https://public-apis.io/
#
# Tutorials : https://www.tutorialspoint.com/
#
# ## CSV
#
# Reading and Writing CSV Files in Python – Real Python : https://realpython.com/python-csv/
#
# csv — CSV File Reading and Writing — Python 3.12.6 documentation : https://docs.python.org/3/library/csv.html
#
# pandas.read_csv — pandas 2.3.3 documentation : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#
# ## VSCode
#
# Find and Replace Window | Microsoft Learn : https://learn.microsoft.com/en-us/visualstudio/ide/how-to-find-and-replace-text-in-files?view=vs-2022
#
# cso.ie : https://cso.ie
#
# andrewbeatty1.pythonanywhere.com/books : https://andrewbeatty1.pythonanywhere.com/books
#
# Big List of Free and Open Public APIs (No Auth Needed) [2025] : https://public-apis.io/
#
# Tutorials : https://www.tutorialspoint.com/
#
# ## CSV
#
# Reading and Writing CSV Files in Python – Real Python : https://realpython.com/python-csv/
#
# csv — CSV File Reading and Writing — Python 3.12.6 documentation : https://docs.python.org/3/library/csv.html
#
# pandas.read_csv — pandas 2.3.3 documentation : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#
# ## VSCode
#
# Find and Replace Window | Microsoft Learn : https://learn.microsoft.com/en-us/visualstudio/ide/how-to-find-and-replace-text-in-files?view=vs-2022

# %% [markdown]
# # Lecture: Acquiring data

# %% [markdown]
# ## Pandas
#
# W3 Schools (pandas) (good for beginners) : https://www.w3schools.com/python/pandas/default.asp
#
# realpython (This goes into some data theory) : https://realpython.com/pandas-dataframe/
#
# pandas Documentation (There is a lot in this) : https://pandas.pydata.org/pandas-docs/stable/index.html
#
# introduction : https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/index.html
#
# comparison with other tools (I found this very useful) : https://pandas.pydata.org/pandas-docs/stable/getting_started/comparison.html
#
# ## Data
#
# AWS Marketplace: Search Results (amazon.com) (list of some data available on AWS) : https://aws.amazon.com/marketplace/search/results?searchTerms=data
#
# Download Sample CSV Files for free - Datalist (some sample data) : https://www.datalist.com/
#
# ## APIs
#
# 🌤️ Free Open-Source Weather API | Open-Meteo.com : https://open-meteo.com/
#
# GitHub REST API documentation - GitHub Docs : https://docs.github.com/en/rest
#
# cso.ie : https://cso.ie
#
# Data.gov.ie : https://data.gov.ie
#
# Big List of Free and Open Public APIs (No Auth Needed) [2025] : https://public-apis.io/

# %% [markdown]
# # Lecture: Cleaning Data and regular expressions

# %% [markdown]
# ## Cleaning data
#
# Pythonic Data Cleaning With pandas and NumPy – Real Python: https://realpython.com/python-data-cleaning-numpy-pandas/
#
# Pandas - Cleaning Data (w3schools): https://www.w3schools.com/python/pandas/pandas_cleaning.asp
#
# ## Regex
#
# **Documentation**
#
# https://www.regular-expressions.info/refcharacters.html
#
# https://docs.python.org/3/library/re.html
#
# ## Tutorials
# Python RegEx (w3schools.com): https://www.w3schools.com/python/python_regex.asp
#
# Regular Expressions: Regexes in Python (Part 1) – Real Python: https://realpython.com/regex-python/
#
# Regular Expressions: Regexes in Python (Part 2) – Real Python: https://realpython.com/regex-python-part-2/
#
# https://www.guru99.com/python-regular-expressions-complete-tutorial.html
#
# https://www.dataquest.io/blog/regular-expressions-data-scientists/
#
# https://www.youtube.com/watch?v=sa-TUpSx1JA
#
#  https://medium.com/@kennymiyasato/regular-expressions-tutorial-with-jupyter-notebooks-6d7df2429695
#
# ## Cheat Sheet
#
# Python_Regular_Expressions_Cheat_Sheet.pdf (datacamp.com) : https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Regular_Expressions_Cheat_Sheet.pdf
#
# ## Other links
# Python String Methods (w3schools.com): https://www.w3schools.com/python/python_strings_methods.asp

# %% [markdown]
# # Lecture: Analysis and some stats

# %% [markdown]
# ## Documentation
#
# pandas.DataFrame.mean — pandas 2.3.3 documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html
#
# Statistical functions (scipy.stats) — SciPy v1.16.2 Manual: https://docs.scipy.org/doc/scipy/reference/stats.html
#
# ## Python and statistics
#
# https://snakebear.science/
# 8.1. Descriptive Statistics — The Python and Pandas Field Guide
# 125book/source at 0a78dbfb48ba5851d8e4ff0b9f792c08584ac904 · CS-DS-125/125book
#
# Python Statistics Fundamentals: How to Describe Your Data – Real Python : https://realpython.com/python-statistics/
#
# https://ethanweed.github.io/pythonbook/03.01-descriptives.html
#
# ## Statistics
#
# https://02402.compute.dtu.dk/enotes/book-IntroStatistics-Python.pdf

# %% [markdown]
# # Lecture: Time Series Data and synthetic data

# %% [markdown]
# # Resources
#
# Python Dates (w3schools): https://www.w3schools.com/python/python_datetime.asp
#
# datetime — Basic date and time types — : Python 3.13.0 documentation https://docs.python.org/3/library/datetime.html#datetime-objects
#
# pandas.to_datetime — pandas 2.2.3 documentation https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html
#
# Time series / date functionality — pandas 2.2.3 documentation https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html
#
# The pandas DataFrame: Make Working With Data Delightful – Real Python https://realpython.com/pandas-dataframe/
#
# pandas.date_range — pandas 2.2.3 documentation https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.date_range.html
#
# ## Random
#
# Random Generator — NumPy v2.1 Manual https://numpy.org/doc/stable/reference/random/generator.html
#
# Using the NumPy Random Number Generator – Real Python https://realpython.com/python-random/
#
# Introduction to Random Numbers in NumPy https://numpy.org/doc/stable/reference/random/index.html
#
# ## Poisson
#
# Poisson distribution - Wikipedia https://en.wikipedia.org/wiki/Poisson_distribution
#
# Poisson Distribution https://www.statisticshowto.com/probability-and-statistics/poisson-distribution/
#
# numpy.random.Generator.poisson — NumPy v2.1 Manual https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.poisson.html
#
# ## Datasets
#
# DataHub Collections (datahub.io) https://datahub.io/collections
#
# CO2 PPM - Trends in Atmospheric Carbon Dioxide https://datahub.io/core/co2-ppm
#
# Data.gov.ie https://data.gov.ie
#
# Home - CSO - Central Statistics Office https://www.cso.ie
#
# Knock Airport Monthly Data - Dataset - data.gov.ie https://data.gov.ie/dataset/knock-airport-monthly-data
